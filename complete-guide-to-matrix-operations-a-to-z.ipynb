# %% [markdown]
# # 🌱 🔢 Complete Guide to Matrix Operations A to Z
#
# Welcome to the comprehensive guide on matrix operations! This notebook is designed to provide you with an in-depth understanding of matrix operations, from basic arithmetic to advanced decompositions and applications in data science and machine learning.
#
# ## Table of Contents
# 1. [Basics of Matrices](#1-basics-of-matrices)
# 2. [Matrix Arithmetic](#2-matrix-arithmetic)
# 3. [Matrix Properties](#3-matrix-properties)
# 4. [Special Matrices](#4-special-matrices)
# 5. [Matrix Decomposition](#5-matrix-decomposition)
# 6. [Solving Linear Systems](#6-solving-linear-systems)
# 7. [Matrix Calculus](#7-matrix-calculus)
# 8. [Advanced Topics](#8-advanced-topics)
# 9. [Practical Applications](#9-practical-applications)
# 10. [Python Implementation](#10-python-implementation)
# 11. [Performance Considerations](#11-performance-considerations)
# 12. [Exercises and Challenges](#12-exercises-and-challenges)
#
# ## Introduction
#
# Matrix operations are fundamental to many fields of mathematics, science, and engineering. By understanding these operations, you will be better equipped to handle complex data analysis tasks and develop advanced machine learning models.
#
# Let's dive in!

# %% [markdown]
# <a id="1-basics-of-matrices"></a>
# ## 1. Basics of Matrices
#
# ### Definitions and Notations
# A **matrix** is a rectangular array of numbers arranged in rows and columns. Matrices are denoted by uppercase letters (e.g., $A$), and elements of a matrix are denoted by lowercase letters with subscripts indicating their position (e.g., $a_{ij}$).
#
# ### Types of Matrices
# - **Square Matrix**: A matrix with the same number

# %%
import numpy as np

# Example: Creating Different Types of Matrices

# Square Matrix
square_matrix = np.array([[1, 2], [3, 4]])
print("Square Matrix:\n", square_matrix)

# Diagonal Matrix
diagonal_matrix = np.diag([1, 2, 3])
print("Diagonal Matrix:\n", diagonal_matrix)

# Identity Matrix
identity_matrix = np.eye(3)
print("Identity Matrix:\n", identity_matrix)

# Zero Matrix
zero_matrix = np.zeros((2, 3))
print("Zero Matrix:\n", zero_matrix)
# Out:
# Square Matrix:
#  [[1 2]
#  [3 4]]
# Diagonal Matrix:
#  [[1 0 0]
#  [0 2 0]
#  [0 0 3]]
# Identity Matrix:
#  [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# Zero Matrix:
#  [[0. 0. 0.]
#  [0. 0. 0.]]

# %% [markdown]
# <a id="2-matrix-arithmetic"></a>
# ## 2. Matrix Arithmetic
#
# ### Addition and Subtraction
# Matrix addition and subtraction are performed element-wise. Two matrices must have the same dimensions to be added or subtracted.
#
# ### Scalar Multiplication
# Scalar multiplication involves multiplying each element of a matrix by a scalar value.
#
# ### Matrix Multiplication
# Matrix multiplication is performed by taking the dot product of rows and columns. The number of columns in the first matrix must equal the number of rows in the second matrix.
#
# ### Element-wise Operations
# Element-wise operations (Hadamard product) are performed by multiplying corresponding elements of two matrices of the same dimensions.

# %%
# Matrix Addition
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
C = A + B
print("Matrix Addition:\n", C)

# Matrix Subtraction
D = A - B
print("Matrix Subtraction:\n", D)

# Scalar Multiplication
scalar = 2
E = scalar * A
print("Scalar Multiplication:\n", E)

# Matrix Multiplication
F = np.dot(A, B)
print("Matrix Multiplication:\n", F)

# Element-wise Multiplication
G = A * B
print("Element-wise Multiplication:\n", G)
# Out:
# Matrix Addition:
#  [[ 6  8]
#  [10 12]]
# Matrix Subtraction:
#  [[-4 -4]
#  [-4 -4]]
# Scalar Multiplication:
#  [[2 4]
#  [6 8]]
# Matrix Multiplication:
#  [[19 22]
#  [43 50]]
# Element-wise Multiplication:
#  [[ 5 12]
#  [21 32]]

# %% [markdown]
# <a id="3-matrix-properties"></a>
# ## 3. Matrix Properties
#
# ### Transpose of a Matrix
# The transpose of a matrix is obtained by swapping its rows and columns.
#
# ### Symmetric and Skew-Symmetric Matrices
# - **Symmetric Matrix**: A matrix that is equal to its transpose.
# - **Skew-Symmetric Matrix**: A matrix that is equal to the negation of its transpose.
#
# ### Determinant of a Matrix
# The determinant is a scalar value that can be computed from the elements of a square matrix and encodes certain properties of the matrix.
#
# ### Inverse of a Matrix
# The inverse of a matrix $A$ is a matrix $A^{-1}$ such that $AA^{-1} = A^{-1}A = I$, where $I$ is the identity matrix.

# %%
# Transpose of a Matrix
A = np.array([[1, 2], [3, 4]])
A_transpose = A.T
print("Transpose of Matrix A:\n", A_transpose)

# Symmetric Matrix
symmetric_matrix = np.array([[1, 2, 3], [2, 4, 5], [3, 5, 6]])
print("Symmetric Matrix:\n", symmetric_matrix)

# Skew-Symmetric Matrix
skew_symmetric_matrix = np.array([[0, -2, 1], [2, 0, -4], [-1, 4, 0]])
print("Skew-Symmetric Matrix:\n", skew_symmetric_matrix)

# Determinant of a Matrix
determinant = np.linalg.det(A)
print("Determinant of Matrix A:", determinant)

# Inverse of a Matrix
inverse_A = np.linalg.inv(A)
print("Inverse of Matrix A:\n", inverse_A)
# Out:
# Transpose of Matrix A:
#  [[1 3]
#  [2 4]]
# Symmetric Matrix:
#  [[1 2 3]
#  [2 4 5]
#  [3 5 6]]
# Skew-Symmetric Matrix:
#  [[ 0 -2  1]
#  [ 2  0 -4]
#  [-1  4  0]]
# Determinant of Matrix A: -2.0000000000000004
# Inverse of Matrix A:
#  [[-2.   1. ]
#  [ 1.5 -0.5]]

# %% [markdown]
# <a id="4-special-matrices"></a>
# ## 4. Special Matrices
#
# ### Identity Matrix
# The identity matrix $I$ is a square matrix with ones on the diagonal and zeros elsewhere.
#
# ### Diagonal Matrix
# A diagonal matrix is a square matrix in which all off-diagonal elements are zero.
#
# ### Orthogonal Matrix
# An orthogonal matrix $Q$ satisfies $Q^T Q = QQ^T = I$, where $Q^T$ is the transpose of $Q$ and $I$ is the identity matrix.
#
# ### Sparse Matrix
# A sparse matrix is a matrix in which most of the elements are zero.

# %%
# Identity Matrix
identity_matrix = np.eye(3)
print("Identity Matrix:\n", identity_matrix)

# Diagonal Matrix
diagonal_matrix = np.diag([1, 2, 3])
print("Diagonal Matrix:\n", diagonal_matrix)

# Orthogonal Matrix
Q = np.array([[1, 0], [0, -1]])
print("Orthogonal Matrix:\n", Q)
print("Q^T Q:\n", np.dot(Q.T, Q))

# Sparse Matrix
from scipy.sparse import csr_matrix

sparse_matrix = csr_matrix([[1, 0, 0], [0, 0, 3], [4, 0, 0]])
print("Sparse Matrix:\n", sparse_matrix)
print("Dense Representation of Sparse Matrix:\n", sparse_matrix.todense())
# Out:
# Identity Matrix:
#  [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# Diagonal Matrix:
#  [[1 0 0]
#  [0 2 0]
#  [0 0 3]]
# Orthogonal Matrix:
#  [[ 1  0]
#  [ 0 -1]]
# Q^T Q:
#  [[1 0]
#  [0 1]]
# Sparse Matrix:
#    (0, 0)	1
#   (1, 2)	3
#   (2, 0)	4
# Dense Representation of Sparse Matrix:
#  [[1 0 0]
#  [0 0 3]
#  [4 0 0]]

# %% [markdown]
# <a id="5-matrix-decomposition"></a>
# ## 5. Matrix Decomposition
#
# ### LU Decomposition
# LU decomposition factorizes a matrix as the product of a lower triangular matrix and an upper triangular matrix.
#
# ### QR Decomposition
# QR decomposition factorizes a matrix into an orthogonal matrix $Q$ and an upper triangular matrix $R$.
#
# ### Cholesky Decomposition
# Cholesky decomposition factorizes a symmetric, positive-definite matrix into a lower triangular matrix and its transpose.
#
# ### Eigen Decomposition
# Eigen decomposition factorizes a matrix into its eigenvalues and eigenvectors.
#
# ### Singular Value Decomposition (SVD)
# SVD factorizes a matrix into three matrices $U$, $\Sigma$, and $V^T$, where $U$ and $V$ are orthogonal matrices and $\Sigma$ is a diagonal matrix.

# %%
# LU Decomposition
from scipy.linalg import lu

A = np.array([[4, 3], [6, 3]])
P, L, U = lu(A)
print("LU Decomposition:\nP:\n", P, "\nL:\n", L, "\nU:\n", U)

# QR Decomposition
Q, R = np.linalg.qr(A)
print("QR Decomposition:\nQ:\n", Q, "\nR:\n", R)

# Cholesky Decomposition
B = np.array([[4, 2], [2, 2]])
L = np.linalg.cholesky(B)
print("Cholesky Decomposition:\n", L)

# Eigen Decomposition
eigenvalues, eigenvectors = np.linalg.eig(A)
print("Eigenvalues:\n", eigenvalues)
print("Eigenvectors:\n", eigenvectors)

# Singular Value Decomposition (SVD)
U, S, VT = np.linalg.svd(A)
print("Singular Value Decomposition:\nU:\n", U, "\nS:\n", S, "\nVT:\n", VT)
# Out:
# LU Decomposition:
# P:
#  [[0. 1.]
#  [1. 0.]]
# L:
#  [[1.         0.        ]
#  [0.66666667 1.        ]]
# U:
#  [[6. 3.]
#  [0. 1.]]
# QR Decomposition:
# Q:
#  [[-0.5547002  -0.83205029]
#  [-0.83205029  0.5547002 ]]
# R:
#  [[-7.21110255 -4.16025147]
#  [ 0.         -0.83205029]]
# Cholesky Decomposition:
#  [[2. 0.]
#  [1. 1.]]
# Eigenvalues:
#  [ 7.77200187 -0.77200187]
# Eigenvectors:
#  [[ 0.62246561 -0.53222953]
#  [ 0.78264715  0.8466001 ]]
# Singular Value Decomposition:
# U:
#  [[-0.59581566 -0.80312122]
#  [-0.80312122  0.59581566]]
# S:
#  [8.33557912 0.71980602]
# VT:
#  [[-0.86400595 -0.50348159]
#  [ 0.50348159 -0.86400595]]

# %% [markdown]
# <a id="6-solving-linear-systems"></a>
# ## 6. Solving Linear Systems
#
# ### Gaussian Elimination
# A method to solve linear systems by transforming the coefficient matrix into an upper triangular form.
#
# ### Matrix Inversion Method
# Solving a system of linear equations using the inverse of the coefficient matrix.
#
# ### Using LU Decomposition
# Using LU decomposition to solve linear systems efficiently.
#
# ### Iterative Methods
# Iterative methods like Jacobi and Gauss-Seidel for solving linear systems.

# %%
# Gaussian Elimination
from scipy.linalg import solve

A = np.array([[3, 2], [1, 2]])
b = np.array([5, 5])
x = solve(A, b)
print("Solution using Gaussian Elimination:\n", x)

# Matrix Inversion Method
A_inv = np.linalg.inv(A)
x = np.dot(A_inv, b)
print("Solution using Matrix Inversion:\n", x)

# Using LU Decomposition
P, L, U = lu(A)
y = np.linalg.solve(L, np.dot(P.T, b))
x = np.linalg.solve(U, y)
print("Solution using LU Decomposition:\n", x)

# Iterative Methods (Jacobi)
def jacobi(A, b, x0, tol=1e-10, max_iterations=100):
    x = x0
    D = np.diag(A)
    R = A - np.diagflat(D)
    for _ in range(max_iterations):
        x_new = (b - np.dot(R, x)) / D
        if np.linalg.norm(x_new - x) < tol:
            break
        x = x_new
    return x

x0 = np.zeros_like(b)
x_jacobi = jacobi(A, b, x0)
print("Solution using Jacobi Iterative Method:\n", x_jacobi)
# Out:
# Solution using Gaussian Elimination:
#  [0.  2.5]
# Solution using Matrix Inversion:
#  [4.4408921e-16 2.5000000e+00]
# Solution using LU Decomposition:
#  [0.  2.5]
# Solution using Jacobi Iterative Method:
#  [0.  2.5]

# %% [markdown]
# <a id="7-matrix-calculus"></a>
# ## 7. Matrix Calculus
#
# ### Derivatives of Matrix Functions
# Matrix calculus extends traditional calculus to functions involving matrices.
#
# ### Gradients and Hessians in Matrix Form
# Gradients and Hessians are crucial in optimization problems and can be represented in matrix form.

# %%
import sympy as sp

# Define a square matrix A and a column vector x
A = sp.Matrix([[sp.Symbol('a11'), sp.Symbol('a12')], [sp.Symbol('a21'), sp.Symbol('a22')]])
x = sp.Matrix([sp.Symbol('x1'), sp.Symbol('x2')])

# Define the expression x^T * A * x
expr = x.T * A * x

# Compute the derivative with respect to x
derivative = sp.Matrix([sp.diff(expr[0], x[i]) for i in range(x.shape[0])])
print("Matrix Derivative:\n", derivative)

# Example: Gradient
f = x.T * x  # A simple quadratic form
gradient = sp.Matrix([sp.diff(f[0], x[i]) for i in range(x.shape[0])])
print("Gradient:\n", gradient)

# Example: Hessian
hessian = sp.hessian(f[0], x)
print("Hessian:\n", hessian)
# Out:
# Matrix Derivative:
#  Matrix([[2*a11*x1 + a12*x2 + a21*x2], [a12*x1 + a21*x1 + 2*a22*x2]])
# Gradient:
#  Matrix([[2*x1], [2*x2]])
# Hessian:
#  Matrix([[2, 0], [0, 2]])

# %% [markdown]
# <a id="8-advanced-topics"></a>
# ## 8. Advanced Topics
#
# ### Kronecker Product
# The Kronecker product is an operation on two matrices of arbitrary size resulting in a block matrix.
#
# ### Hadamard Product
# The Hadamard product is the element-wise product of two matrices.
#
# ### Tensor Operations
# Tensor operations generalize matrix operations to higher dimensions.
#
# ### Applications in Machine Learning
# Matrix operations are fundamental in various machine learning algorithms such as Principal Component Analysis (PCA) and Neural Networks.

# %%
# Kronecker Product
A = np.array([[1, 2], [3, 4]])
B = np.array([[0, 5], [6, 7]])
kronecker_product = np.kron(A, B)
print("Kronecker Product:\n", kronecker_product)

# Hadamard Product
hadamard_product = A * B
print("Hadamard Product:\n", hadamard_product)

# Tensor Operations
tensor_A = np.random.rand(3, 3, 3)
tensor_B = np.random.rand(3, 3, 3)
tensor_product = np.tensordot(tensor_A, tensor_B, axes=([2], [2]))
print("Tensor Product Shape:\n", tensor_product.shape)
# Out:
# Kronecker Product:
#  [[ 0  5  0 10]
#  [ 6  7 12 14]
#  [ 0 15  0 20]
#  [18 21 24 28]]
# Hadamard Product:
#  [[ 0 10]
#  [18 28]]
# Tensor Product Shape:
#  (3, 3, 3, 3)

# %% [markdown]
# <a id="9-practical-applications"></a>
# ## 9. Practical Applications
#
# ### Image Processing with Matrices
# Matrices are used in image processing to represent pixel values and perform transformations.
#
# ### Graph Theory and Adjacency Matrices
# Adjacency matrices represent graphs and are used in network analysis.
#
# ### Network Analysis
# Matrix operations help analyze and model networks in various fields.
#
# ### Optimization Problems
# Matrices are essential in formulating and solving optimization problems.

# %%
# Image Processing Example
from scipy.ndimage import rotate
import matplotlib.pyplot as plt

image = np.random.rand(100, 100)
rotated_image = rotate(image, angle=45)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')

plt.subplot(1, 2, 2)
plt.title("Rotated Image")
plt.imshow(rotated_image, cmap='gray')

plt.show()

# Graph Theory Example
adj_matrix = np.array([[0, 1, 1], [1, 0, 1], [1, 1, 0]])
print("Adjacency Matrix:\n", adj_matrix)

# Network Analysis Example
import networkx as nx

G = nx.from_numpy_array(adj_matrix)
nx.draw(G, with_labels=True)
plt.show()
# Out:
# Adjacency Matrix:
#  [[0 1 1]
#  [1 0 1]
#  [1 1 0]]

# %% [markdown]
# <a id="10-python-implementation"></a>
# ## 10. Python Implementation
#
# ### Numpy for Matrix Operations
# NumPy provides efficient functions for matrix operations and linear algebra.
#
# ### Scipy for Advanced Matrix Functions
# SciPy extends NumPy by providing advanced functions for matrix decompositions and other operations.
#
# ### Real-world Examples and Code Snippets
# Demonstrate the use of NumPy and SciPy in real-world scenarios.

# %%
import numpy as np
import scipy.linalg as la

# Numpy Matrix Operations
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
C = A + B
print("Matrix Addition with NumPy:\n", C)

# Scipy Advanced Matrix Functions
P, L, U = la.lu(A)
print("LU Decomposition with SciPy:\nP:\n", P, "\nL:\n", L, "\nU:\n", U)
# Out:
# Matrix Addition with NumPy:
#  [[ 6  8]
#  [10 12]]
# LU Decomposition with SciPy:
# P:
#  [[0. 1.]
#  [1. 0.]]
# L:
#  [[1.         0.        ]
#  [0.33333333 1.        ]]
# U:
#  [[3.         4.        ]
#  [0.         0.66666667]]

# %% [markdown]
# <a id="11-performance-considerations"></a>
# ## 11. Performance Considerations
#
# ### Computational Complexity of Matrix Operations
# Understanding the computational complexity helps in choosing the right algorithms and optimizing performance.
#
# ### Optimizing Matrix Calculations
# Tips and techniques for optimizing matrix operations to improve efficiency.
#
# ### Handling Large Matrices
# Strategies for handling large matrices that do not fit into memory.

# %%
# Computational Complexity Example
import time

def matrix_multiplication_time(n):
    A = np.random.rand(n, n)
    B = np.random.rand(n, n)
    start_time = time.time()
    np.dot(A, B)
    end_time = time.time()
    return end_time - start_time

sizes = [100, 200, 500, 1000]
times = [matrix_multiplication_time(size) for size in sizes]

plt.plot(sizes, times, marker='o')
plt.xlabel('Matrix Size')
plt.ylabel('Time (seconds)')
plt.title('Matrix Multiplication Time Complexity')
plt.show()

# Optimizing Matrix Calculations Example
A = np.random.rand(1000, 1000)
B = np.random.rand(1000, 1000)
optimized_result = np.dot(A, B)

# %% [markdown]
# <a id="12-exercises-and-challenges"></a>
# ## 12. Exercises and Challenges
#
# ### Practice Problems
# - Perform matrix addition, subtraction, and multiplication for given matrices.
# - Compute the determinant and inverse of given matrices.
# - Solve a system of linear equations using different methods.
#
# ### Real-world Case Studies
# - Apply matrix operations to image processing tasks.
# - Use adjacency matrices for network analysis.
#
# ### Project Ideas
# - Implement matrix decompositions for a given dataset.
# - Optimize a machine learning algorithm using matrix operations.

# %%
# Example Exercise: Solve a System of Linear Equations
A = np.array([[2, -1], [1, 1]])
b = np.array([1, 3])
x = np.linalg.solve(A, b)
print("Solution to the System of Linear Equations:\n", x)

# Example Project Idea: Image Transformation
def apply_transformation(image, transformation_matrix):
    transformed_image = np.dot(transformation_matrix, image)
    return transformed_image

transformation_matrix = np.array([[0.5, 0], [0, 0.5]])
image = np.random.rand(2, 2)
transformed_image = apply_transformation(image, transformation_matrix)
print("Transformed Image:\n", transformed_image)
# Out:
# Solution to the System of Linear Equations:
#  [1.33333333 1.66666667]
# Transformed Image:
#  [[0.13427863 0.48139743]
#  [0.15274879 0.14356419]]

# %% [markdown]
# ## Conclusion
#
# Thank you for exploring this comprehensive guide on matrix operations! We hope this notebook has provided you with valuable insights and practical skills. If you have any questions, suggestions, or just want to discuss any of the topics further, please feel free to reach out or leave a comment.
#
# Happy analyzing, and stay curious!
